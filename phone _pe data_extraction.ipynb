# %% [markdown]
# # TRANSACTION

# %% [markdown]
# # Aggregate_Transaction

# %%
import os
path="C:\\Users\\HP USER\\Documents\\Guvi\\Project\\02_Phone_pe\\pulse\\data\\aggregated\\transaction\\country\\india\\state"
Agg_state_list=os.listdir(path)

# %%
Agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
#Once created the clone of GIT-HUB repository then,
#Required libraries for the program

import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="C:\\Users\\HP USER\\Documents\\Guvi\\Project\\02_Phone_pe\\pulse\\data\\aggregated\\transaction\\country\\india\\state\\"
Agg_state_list=os.listdir(path)
Agg_state_list
#Agg_state_list--> to get the list of states in India

#This is to extract the data's to create a dataframe

clm={'Year':[],'Quarter':[],'State':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for i in Agg_state_list:
    p_i=path+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['transactionData']:
              Name=z['name']
              count=z['paymentInstruments'][0]['count']
              amount=z['paymentInstruments'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quarter'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Agg_Trans=pd.DataFrame(clm)

# %%
Agg_Trans['Transaction_type'].unique()
# Out:
# array(['Recharge & bill payments', 'Peer-to-peer payments',
#        'Merchant payments', 'Financial Services', 'Others'], dtype=object)

# %% [markdown]
# # Map Transaction

# %%
import os
path="C:\\Users\\HP USER\\Documents\\Guvi\\Project\\02_Phone_pe\\pulse\\data\\map\\transaction\\hover\\country\\india\\state"
map_state_list=os.listdir(path)

# %%
import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="C:\\Users\\HP USER\\Documents\\Guvi\\Project\\02_Phone_pe\\pulse\\data\\map\\transaction\\hover\\country\\india\\state\\"
map_state_list=os.listdir(path)
map_state_list
#
# map_state_list--> to get the list of states in India

#This is to extract the data's to create a dataframe

clm={'Year':[],'Quarter':[],'State':[],'Transaction_type':[],'Transaction_count':[],'Transaction_amount':[]}

for i in map_state_list:
    p_i=path+i+"/"
    map_yr=os.listdir(p_i)
    for j in map_yr:
        p_j=p_i+j+"/"
        map_yr_list=os.listdir(p_j)
        for k in map_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Transaction_type'].append(Name)
              clm['Transaction_count'].append(count)
              clm['Transaction_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quarter'].append(int(k.strip('.json')))
#Succesfully created a dataframe
map_Trans=pd.DataFrame(clm)

# %%
map_Trans
# Out:
#                            State  Year  Quarter  \
# 0      andaman-&-nicobar-islands  2018        1
# 1      andaman-&-nicobar-islands  2018        1
# 2      andaman-&-nicobar-islands  2018        1
# 3      andaman-&-nicobar-islands  2018        2
# 4      andaman-&-nicobar-islands  2018        2
# ...                          ...   ...      ...
# 18291                west-bengal  2024        1
# 18292                west-bengal  2024        1
# 18293                west-bengal  2024        1
# 18294                west-bengal  2024        1
# 18295                west-bengal  2024        1
#
#                         Transaction_type  Transaction_count  \
# 0      north and middle andaman district                442
# 1                 south andaman district               5688
# 2                      nicobars district                528
# 3      north and middle andaman district                825
# 4                 south andaman district               9395
# ...

# %% [markdown]
# # Top Transaction

# %%
import os
path="C:\\Users\\HP USER\\Documents\\Guvi\\Project\\02_Phone_pe\\pulse\\data\\top\\transaction\\country\\india\\state"
top_state_list=os.listdir(path)

# %%
import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path_top_trans="C:\\Users\\HP USER\\Documents\\Guvi\\Project\\02_Phone_pe\\pulse\\data\\top\\transaction\\country\\india\\state\\"
top_state_list=os.listdir(path_top_trans)
#Agg_state_list--> to get the list of states in India

#This is to extract the data's to create a dataframe

top_trans_clm={'State':[], 'Year':[],'Quarter':[],'Districts':[],'District_Transaction_count':[],'District_Transaction_amount':[] ,'Pincode':[],
     'Pincode_Transaction_count':[],'Pincode_Transaction_amount':[] }
for i in top_state_list:
    p_i=path_top_trans+i+"/"
    top_yr=os.listdir(p_i)
    for j in top_yr:
        p_j=p_i+j+"/"
        top_yr_list=os.listdir(p_j)
        for k in top_yr_list:
          p_k=p_j+k
          Data=open(p_k,'r')
          D=json.load(Data)
          states_data = D['data']['states']
          if states_data is None:
            stat_name = 'Not Applicable'
            stat_count=0
            stat_amount=0
            for dis in D['data']['districts']:
              dis_name=dis['entityName']
              dis_count=dis['metric']['count']
              dis_amount=dis['metric']['amount']
              for pin in D['data']['pincodes']:
                pin_name=pin['entityName']
                pin_count=pin['metric']['count']
                pin_amount=pin['metric']['amount']
                top_trans_clm['Districts'].append(dis_name)
                top_trans_clm['District_Transaction_count'].append(dis_count)
                top_trans_clm['District_Transaction_amount'].append(dis_amount)              
                top_trans_clm['Pincode'].append(pin_name)        
                top_trans_clm['Pincode_Transaction_count'].append(pin_count)
                top_trans_clm['Pincode_Transaction_amount'].append(pin_amount)
                top_trans_clm['State_Transaction_count'].append(stat_count)
                top_trans_clm['State_Transaction_amount'].append(stat_amount)              
                top_trans_clm['State'].append(i)
                top_trans_clm['Year'].append(j)
                top_trans_clm['Quarter'].append(int(k.strip('.json')))
          else:
            for z in D['data']['states']:
              stat_name=z['entityName']
              stat_count=z['metric']['count']
              stat_amount=z['metric']['amount']
              for dis in D['data']['districts']:
                dis_name=dis['entityName']
                dis_count=dis['metric']['count']
                dis_amount=dis['metric']['amount']
                for pin in D['data']['pincodes']:
                    pin_name=pin['entityName']
                    pin_count=pin['metric']['count']
                    pin_amount=pin['metric']['amount']
                    top_trans_clm['Districts'].append(dis_name)
                    top_trans_clm['District_Transaction_count'].append(dis_count)
                    top_trans_clm['District_Transaction_amount'].append(dis_amount)              
                    top_trans_clm['Pincode'].append(pin_name)
                    top_trans_clm['Pincode_Transaction_count'].append(pin_count)
                    top_trans_clm['Pincode_Transaction_amount'].append(pin_amount)
                    top_trans_clm['State_Transaction_count'].append(stat_count)
                    top_trans_clm['State_Transaction_amount'].append(stat_amount)                     
                    top_trans_clm['State'].append(i)
                    top_trans_clm['Year'].append(j)
                    top_trans_clm['Quarter'].append(int(k.strip('.json')))
#Succesfully created a dataframe
top_Trans=pd.DataFrame(top_trans_clm)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 44
#      42 top_trans_clm['Pincode_Transaction_count'].append(pin_count)
#      43 top_trans_clm['Pincode_Transaction_amount'].append(pin_amount)
# ---> 44 top_trans_clm['State_Transaction_count'].append(stat_count)
#      45 top_trans_clm['State_Transaction_amount'].append(stat_amount)
#      46 top_trans_clm['State'].append(i)
#
# KeyError: 'State_Transaction_count'

# %%
top_Trans
# Out:
#                            State  Year  Quarter          Districts  \
# 0      andaman-&-nicobar-islands  2018        1      south andaman
# 1      andaman-&-nicobar-islands  2018        1      south andaman
# 2      andaman-&-nicobar-islands  2018        1      south andaman
# 3      andaman-&-nicobar-islands  2018        1      south andaman
# 4      andaman-&-nicobar-islands  2018        1      south andaman
# ...                          ...   ...      ...                ...
# 73869                west-bengal  2024        1  paschim medinipur
# 73870                west-bengal  2024        1  paschim medinipur
# 73871                west-bengal  2024        1  paschim medinipur
# 73872                west-bengal  2024        1  paschim medinipur
# 73873                west-bengal  2024        1  paschim medinipur
#
#        District_Transaction_count  District_Transaction_amount Pincode  \
# 0                            5688                 1.256025e+07  744101
# ...

# %% [markdown]
# # USER

# %% [markdown]
# # Aggregate_User

# %%
import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="C:\\Users\\HP USER\\Documents\\Guvi\\Project\\02_Phone_pe\\pulse\\data\\aggregated\\user\\country\\india\\state\\"
Agg_user_state_list=os.listdir(path)
Agg_user_state_list
#Agg_state_list--> to get the list of states in India

#This is to extract the data's to create a dataframe

clm={'State':[], 'Year':[],'Quarter':[],'Registered_Users':[], 'App_opens':[],
     'Brand_name':[],'Registered_Users_of_brand':[], 'Percentage_of_contribution_by_brand':[]}

for i in Agg_user_state_list:
  p_i=path+i+"/"
  Agg_user_yr=os.listdir(p_i)
  for j in Agg_user_yr:
    p_j=p_i+j+"/"
    Agg_user_yr_list=os.listdir(p_j)
    for k in Agg_user_yr_list:
      p_k=p_j+k
      Data=open(p_k,'r')
      D=json.load(Data)
      registered_user=D['data']['aggregated']['registeredUsers']
      app_opens=D['data']['aggregated']['appOpens']
      user_by_device = D['data'].get('usersByDevice', [])
      if user_by_device:  # Check if user_by_device is not None or empty
        for u in user_by_device:
          brand=u.get('brand', 'Not Available')
          brand_count=u.get('count', 0)
          brand_percentage=u.get('percentage', 0)
          clm['Registered_Users'].append(registered_user)
          clm['App_opens'].append(app_opens)
          clm['Brand_name'].append(brand)
          clm['Registered_Users_of_brand'].append(brand_count)
          clm['Percentage_of_contribution_by_brand'].append(brand_percentage)
          clm['State'].append(i)
          clm['Year'].append(j)
          clm['Quarter'].append(int(k.strip('.json')))
      else:
        brand='Not Available'
        brand_count  = 0
        brand_percentage = 0
        clm['Registered_Users'].append(registered_user)
        clm['App_opens'].append(app_opens)
        clm['Brand_name'].append(brand)
        clm['Registered_Users_of_brand'].append(brand_count)
        clm['Percentage_of_contribution_by_brand'].append(brand_percentage)
        clm['State'].append(i)
        clm['Year'].append(j)
        clm['Quarter'].append(int(k.strip('.json')))

      

#Succesfully created a dataframe
Agg_User=pd.DataFrame(clm)

# %%
Agg_User
# Out:
#                           State  Year  Quarter  Registered_Users   App_opens  \
# 0     andaman-&-nicobar-islands  2018        1              6740           0
# 1     andaman-&-nicobar-islands  2018        1              6740           0
# 2     andaman-&-nicobar-islands  2018        1              6740           0
# 3     andaman-&-nicobar-islands  2018        1              6740           0
# 4     andaman-&-nicobar-islands  2018        1              6740           0
# ...                         ...   ...      ...               ...         ...
# 7015                west-bengal  2023        1          26732895   321102681
# 7016                west-bengal  2023        2          27827662   350862668
# 7017                west-bengal  2023        3          28966414   473450373
# 7018                west-bengal  2023        4          30064546  1467442959
# 7019                west-bengal  2024        1          31306843   633526507
#
# ...

# %% [markdown]
# # Map_User

# %%
import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="C:\\Users\\HP USER\\Documents\\Guvi\\Project\\02_Phone_pe\\pulse\\data\\map\\user\\hover\\country\\india\\state\\"
map_user_state_list=os.listdir(path)
#Agg_state_list--> to get the list of states in India

#This is to extract the data's to create a dataframe

clm={'Year':[],'Quarter':[],'State':[],'District':[], 'Registered_Users':[], 'App_opens':[]}

for i in map_user_state_list:
  p_i=path+i+"/"
  map_user_yr=os.listdir(p_i)
  for j in map_user_yr:
    p_j=p_i+j+"/"
    map_user_yr_list=os.listdir(p_j)
    for k in map_user_yr_list:
      p_k=p_j+k
      Data=open(p_k,'r')
      D=json.load(Data)
      registered_user_data=D['data']['hoverData']
      for dist in registered_user_data:
        dist_names=registered_user_data[dist]
        registered_user=dist_names['registeredUsers']
        app_opens_user=dist_names['appOpens']
        clm['Registered_Users'].append(registered_user)
        clm['App_opens'].append(app_opens_user)
        clm['District'].append(dist)
        clm['State'].append(i)
        clm['Year'].append(j)
        clm['Quarter'].append(int(k.strip('.json')))
      #Succesfully created a dataframe
map_User=pd.DataFrame(clm)

# %%
map_User
# Out:
#        Year  Quarter                      State  \
# 0      2018        1  andaman-&-nicobar-islands
# 1      2018        1  andaman-&-nicobar-islands
# 2      2018        1  andaman-&-nicobar-islands
# 3      2018        2  andaman-&-nicobar-islands
# 4      2018        2  andaman-&-nicobar-islands
# ...     ...      ...                        ...
# 18295  2024        1                west-bengal
# 18296  2024        1                west-bengal
# 18297  2024        1                west-bengal
# 18298  2024        1                west-bengal
# 18299  2024        1                west-bengal
#
#                                 District  Registered_Users  App_opens
# 0      north and middle andaman district               632          0
# 1                 south andaman district              5846          0
# 2                      nicobars district               262          0
# 3      north and middle andaman district               911          0
# ...

# %% [markdown]
# # Top_User

# %%
import pandas as pd
import json
import os

#This is to direct the path to get the data as states

path="C:\\Users\\HP USER\\Documents\\Guvi\\Project\\02_Phone_pe\\pulse\\data\\top\\user\\country\\india\\state\\"
top_user_state_list=os.listdir(path)
top_user_state_list
#Agg_state_list--> to get the list of states in India

#This is to extract the data's to create a dataframe

clm={'Year':[],'Quarter':[],'State':[],'Districts':[],'District_Registered_user':[],'Pincode':[],'Pincode_Registered_user':[]}

for i in top_user_state_list:
    p_i=path+i+"/"
    top_user_yr=os.listdir(p_i)
    for j in top_user_yr:
        p_j=p_i+j+"/"
        top_user_yr_list=os.listdir(p_j)
        for k in top_user_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            states_data = D['data']['states']
            if states_data is None:                     
                for dis in D['data']['districts']:
                    dis_name=dis['name']
                    dis_registered_user=dis['registeredUsers']
                    for pin in D['data']['pincodes']:
                        pin_name=pin['name']
                        pin_registered_user=pin['registeredUsers']
                        clm['Districts'].append(dis_name)
                        clm['District_Registered_user'].append(dis_registered_user)                
                        clm['Pincode'].append(pin_name)
                        clm['Pincode_Registered_user'].append(pin_registered_user)                                  
                        clm['State'].append(i)
                        clm['Year'].append(j)
                        clm['Quarter'].append(int(k.strip('.json')))
            else:
                for z in D['data']['states']:
                    state_name=z['name']
                    state_registered_user=z['registeredUsers']
                    for dis in D['data']['districts']:
                        dis_name=dis['name']
                        dis_registered_user=dis['registeredUsers']
                        for pin in D['data']['pincodes']:
                            pin_name=pin['name']
                            pin_registered_user=pin['registeredUsers']
                            clm['Districts'].append(dis_name)
                            clm['District_Registered_user'].append(dis_registered_user)                
                            clm['Pincode'].append(pin_name)
                            clm['Pincode_Registered_user'].append(pin_registered_user)                                  
                            clm['State'].append(i)
                            clm['Year'].append(j)
                            clm['Quarter'].append(int(k.strip('.json')))
#Succesfully created a dataframe
top_Users=pd.DataFrame(clm)

# %%
top_Users
# Out:
#        Year  Quarter                      State        Districts  \
# 0      2018        1  andaman-&-nicobar-islands    south andaman
# 1      2018        1  andaman-&-nicobar-islands    south andaman
# 2      2018        1  andaman-&-nicobar-islands    south andaman
# 3      2018        1  andaman-&-nicobar-islands    south andaman
# 4      2018        1  andaman-&-nicobar-islands    south andaman
# ...     ...      ...                        ...              ...
# 73870  2024        1                west-bengal  purba bardhaman
# 73871  2024        1                west-bengal  purba bardhaman
# 73872  2024        1                west-bengal  purba bardhaman
# 73873  2024        1                west-bengal  purba bardhaman
# 73874  2024        1                west-bengal  purba bardhaman
#
#        District_Registered_user Pincode  Pincode_Registered_user
# 0                          5846  744103                     1608
# ...
